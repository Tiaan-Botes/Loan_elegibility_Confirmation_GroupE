# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\delig\Downloads\raw_data.csv")

df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
pd.set_option('display.max.rows', 700)

# %%
#df2 = df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df2 = df1
#
# NameError: name 'df1' is not defined

# %%
 df['Gender_Filled'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Gender_Filled         0
# dtype: int64

# %%
df1 = df.drop('Gender', axis= 1)

# %%
df1['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df1['Married'].mode()
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
df1['Married'] = df1['Married'].fillna(df1['Married'].mode()[0])

# %%
df1['Self_Employed'].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df1['Self_Employed'] = df1['Self_Employed'].fillna(df1['Self_Employed'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Gender_Filled         0
# dtype: int64

# %%
df1['LoanAmount'] = df1['LoanAmount'].fillna(df1['LoanAmount'].mean())

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Gender_Filled         0
# dtype: int64

# %%
df1['Loan_Amount_Term'] = df1['Loan_Amount_Term'].fillna(df1['Loan_Amount_Term'].mean())

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Gender_Filled         0
# dtype: int64

# %%
df1['Credit_History'].median()
# Out:
# 1.0

# %%
df1['Credit_History'] = df1['Credit_History'].fillna(df1['Credit_History'].median())

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Married               0
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# Gender_Filled         0
# dtype: int64

# %%
df1['Dependents'] = df1['Dependents'].str.replace('+','')

# %%
df1['Dependents'] = df1['Dependents'].astype(float)

# %%
df1['Dependents'] = df1['Dependents'].fillna(df1['Dependents'].mean())

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Gender_Filled        0
# dtype: int64

# %%
df1
# Out:
#       Loan_ID Married  Dependents     Education Self_Employed  \
# 0    LP001002      No    0.000000      Graduate            No
# 1    LP001003     Yes    1.000000      Graduate            No
# 2    LP001005     Yes    0.000000      Graduate           Yes
# 3    LP001006     Yes    0.000000  Not Graduate            No
# 4    LP001008      No    0.000000      Graduate            No
# 5    LP001011     Yes    2.000000      Graduate           Yes
# 6    LP001013     Yes    0.000000  Not Graduate            No
# 7    LP001014     Yes    3.000000      Graduate            No
# 8    LP001018     Yes    2.000000      Graduate            No
# 9    LP001020     Yes    1.000000      Graduate            No
# 10   LP001024     Yes    2.000000      Graduate            No
# 11   LP001027     Yes    2.000000      Graduate            No
# 12   LP001028     Yes    2.000000      Graduate            No
# 13   LP001029      No    0.000000      Graduate            No
# ...

# %%
df1['Dependents'] = df1['Dependents'].round(decimals=2)

# %%
df1['CoapplicantIncome'] =df1['CoapplicantIncome'].round(decimals=2)
df1['LoanAmount'] = df1['LoanAmount'].round(decimals=2)

# %%
column_to_move = df1.pop('Gender_Filled')

df1.insert(3,'Gender_Filled',column_to_move)

# %%
df1.rename(columns = {'Gender_Filled' : 'Gender'}, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Married              0
# Dependents           0
# Gender               0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#df1.to_csv(r'C:\Users\delig\Documents\Python Scripts\machine_learning_course\Loans.csv', index = False)

# %%
df1
# Out:
#       Loan_ID Married  Dependents  Gender     Education Self_Employed  \
# 0    LP001002      No        0.00    Male      Graduate            No
# 1    LP001003     Yes        1.00    Male      Graduate            No
# 2    LP001005     Yes        0.00    Male      Graduate           Yes
# 3    LP001006     Yes        0.00    Male  Not Graduate            No
# 4    LP001008      No        0.00    Male      Graduate            No
# 5    LP001011     Yes        2.00    Male      Graduate           Yes
# 6    LP001013     Yes        0.00    Male  Not Graduate            No
# 7    LP001014     Yes        3.00    Male      Graduate            No
# 8    LP001018     Yes        2.00    Male      Graduate            No
# 9    LP001020     Yes        1.00    Male      Graduate            No
# 10   LP001024     Yes        2.00    Male      Graduate            No
# 11   LP001027     Yes        2.00    Male      Graduate            No
# ...

# %%
df5['LoanAmount'].unique()
# Out:
# array([146.41, 128.  ,  66.  , 120.  , 141.  , 267.  ,  95.  , 158.  ,
#        168.  , 349.  ,  70.  , 109.  , 200.  , 114.  ,  17.  , 125.  ,
#        100.  ,  76.  , 133.  , 115.  , 104.  , 315.  , 116.  , 112.  ,
#        151.  , 191.  , 122.  , 110.  ,  35.  , 201.  ,  74.  , 106.  ,
#        320.  , 144.  , 184.  ,  80.  ,  47.  ,  75.  , 134.  ,  96.  ,
#         88.  ,  44.  , 286.  ,  97.  , 135.  , 180.  ,  99.  , 165.  ,
#        258.  , 126.  , 312.  , 136.  , 172.  ,  81.  , 187.  , 113.  ,
#        176.  , 130.  , 111.  , 167.  , 265.  ,  50.  , 210.  , 175.  ,
#        131.  , 188.  ,  25.  , 137.  , 160.  , 225.  , 216.  ,  94.  ,
#        139.  , 152.  , 118.  , 185.  , 154.  ,  85.  , 259.  , 194.  ,
#         93.  , 370.  , 182.  , 650.  , 102.  , 290.  ,  84.  , 242.  ,
#        129.  ,  30.  , 244.  , 600.  , 255.  ,  98.  , 275.  , 121.  ,
#         63.  , 700.  ,  87.  , 101.  , 495.  ,  67.  ,  73.  , 260.  ,
# ...

# %%
df1['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df5 = df1

# %%
df5.describe([x*0.1 for x in range(10)])
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  614.000000       614.000000         614.000000  614.000000
# mean     0.762866      5403.459283        1621.245798  146.412085
# std      1.002718      6109.041673        2926.248369   84.037468
# min      0.000000       150.000000           0.000000    9.000000
# 0%       0.000000       150.000000           0.000000    9.000000
# 10%      0.000000      2216.100000           0.000000   72.300000
# 20%      0.000000      2605.400000           0.000000   96.000000
# 30%      0.000000      3050.400000           0.000000  109.900000
# 40%      0.000000      3406.800000           0.000000  119.200000
# 50%      0.000000      3812.500000        1188.500000  129.000000
# 60%      1.000000      4343.600000        1689.600000  140.000000
# 70%      1.000000      5185.600000        2083.000000  155.000000
# 80%      2.000000      6252.400000        2535.000000  180.000000
# ...

# %%
import seaborn as sns

sns.boxplot(x = df6['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
sns.displot(data = df5['ApplicantIncome'])
# Out:
# C:\Users\delig\anaconda3\envs\machine_learning\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
outlier = ['ApplicantIncome','LoanAmount']

df6 = df5[df[outlier]<df[outlier].quantile(0.9)]

# %%
sns.boxplot(x = df6['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
sns.boxplot(x = df6['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount'>

# %%
df7['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df7['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df7['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df7['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df7
# Out:
#       Loan_ID Married  Dependents  Gender     Education Self_Employed  \
# 0    LP001002      No        0.00    Male      Graduate            No
# 1    LP001003     Yes        1.00    Male      Graduate            No
# 2    LP001005     Yes        0.00    Male      Graduate           Yes
# 3    LP001006     Yes        0.00    Male  Not Graduate            No
# 4    LP001008      No        0.00    Male      Graduate            No
# 5    LP001011     Yes        2.00    Male      Graduate           Yes
# 6    LP001013     Yes        0.00    Male  Not Graduate            No
# 7    LP001014     Yes        3.00    Male      Graduate            No
# 8    LP001018     Yes        2.00    Male      Graduate            No
# 10   LP001024     Yes        2.00    Male      Graduate            No
# 11   LP001027     Yes        2.00    Male      Graduate            No
# 12   LP001028     Yes        2.00    Male      Graduate            No
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

one = OneHotEncoder()

encoded = pd.DataFrame(one.fit_transform(df7[['Property_Area']]).toarray())

df8 = df7.join(encoded)

# %%
from category_encoders import OneHotEncoder

ohe = OneHotEncoder(
    use_cat_names= True,
    cols=['Property_Area','Married','Loan_Status','Education','Self_Employed','Gender']
)

df8 = ohe.fit_transform(df7)

df8.head()
# Out:
#     Loan_ID  Married_No  Married_Yes  Dependents  Gender_Male  Gender_Female  \
# 0  LP001002           1            0         0.0            1              0
# 1  LP001003           0            1         1.0            1              0
# 2  LP001005           0            1         0.0            1              0
# 3  LP001006           0            1         0.0            1              0
# 4  LP001008           1            0         0.0            1              0
#
#    Education_Graduate  Education_Not Graduate  Self_Employed_No  \
# 0                   1                       0                 1
# 1                   1                       0                 1
# 2                   1                       0                 0
# 3                   0                       1                 1
# 4                   1                       0                 1
#
#    Self_Employed_Yes  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %%
df8
# Out:
#       Loan_ID  Married_No  Married_Yes  Dependents  Gender_Male  \
# 0    LP001002           1            0        0.00            1
# 1    LP001003           0            1        1.00            1
# 2    LP001005           0            1        0.00            1
# 3    LP001006           0            1        0.00            1
# 4    LP001008           1            0        0.00            1
# 5    LP001011           0            1        2.00            1
# 6    LP001013           0            1        0.00            1
# 7    LP001014           0            1        3.00            1
# 8    LP001018           0            1        2.00            1
# 10   LP001024           0            1        2.00            1
# 11   LP001027           0            1        2.00            1
# 12   LP001028           0            1        2.00            1
# 13   LP001029           1            0        0.00            1
# 14   LP001030           0            1        2.00            1
# ...

# %%
df8.to_csv(r'C:\Users\delig\Documents\Python Scripts\machine_learning_course\Loans.csv', index = False)

# %%
df8.isnull().sum()
# Out:
# Loan_ID                    0
# Married_No                 0
# Married_Yes                0
# Dependents                 0
# Gender_Male                0
# Gender_Female              0
# Education_Graduate         0
# Education_Not Graduate     0
# Self_Employed_No           0
# Self_Employed_Yes          0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Property_Area_Urban        0
# Property_Area_Rural        0
# Property_Area_Semiurban    0
# Loan_Status_Y              0
# Loan_Status_N              0
# dtype: int64
